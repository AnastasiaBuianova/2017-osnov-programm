# %%
import sys
import re

# %%
import sys
import re
'''
#Original
file = open('test.txt', 'r', encoding='utf-8')
letters = open('transliterated_letters.txt', 'r', encoding='utf-8')

index = 0
translit = {}

for line in letters:
    line = line.replace('\n', '')
    line = line.split('    ')
    translit[line[0]] = line[1]
    
for word in file:
    word = word.strip().split(' ')
    for w in word:
        w = re.sub('([?!,.—:;()])', '', w)
        while index >= 0:
            index += 1
            break
        tr = w
        for key, value in translit.items():
                tr = tr.replace(key, value)
        print('%d\t'% (index) + '%s\t_\t_\t_\t_\t_\t_\t_\t'% (w.lower()) + 'Translit=%s'% (tr))
'''

file = open('wiki.txt', 'r', encoding='utf-8')
#file = open('test.txt', 'r', encoding='utf-8')
letters = open('transliterated_letters.txt', 'r', encoding='utf-8')
#file = sys.stdin
sindex = 0

translit = {}

for line in letters:
    line = line.replace('\n', '')
    line = line.split('    ')
    translit[line[0]] = line[1]
    
for word in file:
    if word.strip() == '': continue
    index = 0
    word = re.sub('([?!,.—:;()])', ' \g<1> ', word)
    word = word.strip().split(' ')
    for w in word:
        if w.strip() == '': continue
        while index >= 0:
            index += 1
            break
        tr = w
        for key, value in translit.items():
                tr = tr.replace(key, value)
        print('%d\t'% (index) + '%s\t_\t_\t_\t_\t_\t_\t_\t'% (w.lower()) + 'Translit=%s'% (tr))
    sindex += 1
    print()
file.close()
# Out:
# 1	1	_	_	_	_	_	_	_	Translit=1
# 2	.	_	_	_	_	_	_	_	Translit=.
# 3	апріля	_	_	_	_	_	_	_	Translit=aprіlja
# 4	(	_	_	_	_	_	_	_	Translit=(
# 5	перше	_	_	_	_	_	_	_	Translit=Ojershje
# 6	апріля	_	_	_	_	_	_	_	Translit=aprіlja
# 7	)	_	_	_	_	_	_	_	Translit=)
# 8	—	_	_	_	_	_	_	_	Translit=—
# 9	91	_	_	_	_	_	_	_	Translit=91
# 10	.	_	_	_	_	_	_	_	Translit=.
# 11	день	_	_	_	_	_	_	_	Translit=djenь
# 12	рока	_	_	_	_	_	_	_	Translit=roka
# 13	(	_	_	_	_	_	_	_	Translit=(
# 14	92	_	_	_	_	_	_	_	Translit=92
# 15	.	_	_	_	_	_	_	_	Translit=.
# 16	в	_	_	_	_	_	_	_	Translit=v
# 17	переступнім	_	_	_	_	_	_	_	Translit=pjerjestupnіm
# 18	роцї	_	_	_	_	_	_	_	Translit=rotsї
# 19	)	_	_	_	_	_	_	_	Translit=)
# 20	в	_	_	_	_	_	_	_	Translit=v
# 21	ґреґоріаньскім	_	_	_	_	_	_	_	Translit=ґrjeґorіanьskіm
# 22	календарю	_	_	_	_	_	_	_	Translit=kaljendarju
# 23	.	_	_	_	_	_	_	_	Translit=.
# 24	до	_	_	_	_	_	_	_	Translit=Do
# 25	кінце	_	_	_	_	_	_	_	Translit=kіntsje
# 26	рока	_	_	_	_	_	_	_	Translit=roka
# 27	оставать	_	_	_	_	_	_	_	Translit=ostavatь
# 28	.	_	_	_	_	_	_	_	Translit=.
#
# 1	общую	_	_	_	_	_	_	_	Translit=Rbsh'uju
# 2	схему	_	_	_	_	_	_	_	Translit=shjemu
# 3	течений	_	_	_	_	_	_	_	Translit=tjechjenij
# 4	тихого	_	_	_	_	_	_	_	Translit=Tihogo
# 5	океана	_	_	_	_	_	_	_	Translit=okjeana
# 6	определяют	_	_	_	_	_	_	_	Translit=oprjedjeljajut
# 7	закономерности	_	_	_	_	_	_	_	Translit=zakonomjernosti
# 8	общей	_	_	_	_	_	_	_	Translit=obsh'jej
# 9	циркуляции	_	_	_	_	_	_	_	Translit=tsirkuljatsii
# 10	атмосферы	_	_	_	_	_	_	_	Translit=atmosfjery
# 11	.	_	_	_	_	_	_	_	Translit=.
# 12	северо-восточный	_	_	_	_	_	_	_	Translit=Sjevjero-vostochnyj
# 13	пассат	_	_	_	_	_	_	_	Translit=passat
# 14	северного	_	_	_	_	_	_	_	Translit=sjevjernogo
# 15	полушария	_	_	_	_	_	_	_	Translit=polusharija
# 16	способствует	_	_	_	_	_	_	_	Translit=sposobstvujet
# 17	возникновению	_	_	_	_	_	_	_	Translit=vozniknovjeniju
# 18	северо-пассатного	_	_	_	_	_	_	_	Translit=Sjevjero-Oassatnogo
# 19	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 20	,	_	_	_	_	_	_	_	Translit=,
# 21	пересекающего	_	_	_	_	_	_	_	Translit=pjerjesjekajush'jego
# 22	океан	_	_	_	_	_	_	_	Translit=okjean
# 23	от	_	_	_	_	_	_	_	Translit=ot
# 24	центрально-американского	_	_	_	_	_	_	_	Translit=Tsjentralьno-amjerikanskogo
# 25	побережья	_	_	_	_	_	_	_	Translit=pobjerjezhьja
# 26	до	_	_	_	_	_	_	_	Translit=do
# 27	филиппинских	_	_	_	_	_	_	_	Translit=Filippinskih
# 28	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 29	.	_	_	_	_	_	_	_	Translit=.
# 30	далее	_	_	_	_	_	_	_	Translit=Daljeje
# 31	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 32	разделяется	_	_	_	_	_	_	_	Translit=razdjeljajetsja
# 33	на	_	_	_	_	_	_	_	Translit=na
# 34	два	_	_	_	_	_	_	_	Translit=dva
# 35	рукава	_	_	_	_	_	_	_	Translit=rukava
# 36	:	_	_	_	_	_	_	_	Translit=:
# 37	один	_	_	_	_	_	_	_	Translit=odin
# 38	отклоняется	_	_	_	_	_	_	_	Translit=otklonjajetsja
# 39	к	_	_	_	_	_	_	_	Translit=k
# 40	югу	_	_	_	_	_	_	_	Translit=jugu
# 41	и	_	_	_	_	_	_	_	Translit=i
# 42	частью	_	_	_	_	_	_	_	Translit=chastьju
# 43	питает	_	_	_	_	_	_	_	Translit=pitajet
# 44	экваториальное	_	_	_	_	_	_	_	Translit=Ekvatorialьnoje
# 45	противотечение	_	_	_	_	_	_	_	Translit=protivotjechjenije
# 46	,	_	_	_	_	_	_	_	Translit=,
# 47	а	_	_	_	_	_	_	_	Translit=a
# 48	частью	_	_	_	_	_	_	_	Translit=chastьju
# 49	растекается	_	_	_	_	_	_	_	Translit=rastjekajetsja
# 50	по	_	_	_	_	_	_	_	Translit=po
# 51	бассейнам	_	_	_	_	_	_	_	Translit=bassjejnam
# 52	индонезийских	_	_	_	_	_	_	_	Translit=indonjezijskih
# 53	морей	_	_	_	_	_	_	_	Translit=morjej
# 54	.	_	_	_	_	_	_	_	Translit=.
# 55	северный	_	_	_	_	_	_	_	Translit=Sjevjernyj
# 56	рукав	_	_	_	_	_	_	_	Translit=rukav
# 57	следует	_	_	_	_	_	_	_	Translit=sljedujet
# 58	в	_	_	_	_	_	_	_	Translit=v
# 59	восточно-китайское	_	_	_	_	_	_	_	Translit=Vostochno-Kitajskoje
# 60	море	_	_	_	_	_	_	_	Translit=morje
# 61	и	_	_	_	_	_	_	_	Translit=i
# 62	,	_	_	_	_	_	_	_	Translit=,
# 63	выходя	_	_	_	_	_	_	_	Translit=vyhodja
# 64	из	_	_	_	_	_	_	_	Translit=iz
# 65	него	_	_	_	_	_	_	_	Translit=njego
# 66	южнее	_	_	_	_	_	_	_	Translit=juzhnjeje
# 67	острова	_	_	_	_	_	_	_	Translit=ostrova
# 68	кюсю	_	_	_	_	_	_	_	Translit=Kjusju
# 69	,	_	_	_	_	_	_	_	Translit=,
# 70	даёт	_	_	_	_	_	_	_	Translit=daёt
# 71	начало	_	_	_	_	_	_	_	Translit=nachalo
# 72	мощному	_	_	_	_	_	_	_	Translit=mosh'nomu
# 73	тёплому	_	_	_	_	_	_	_	Translit=tёplomu
# 74	течению	_	_	_	_	_	_	_	Translit=tjechjeniju
# 75	куросио	_	_	_	_	_	_	_	Translit=Kurosio
# 76	.	_	_	_	_	_	_	_	Translit=.
# 77	это	_	_	_	_	_	_	_	Translit=Eto
# 78	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 79	следует	_	_	_	_	_	_	_	Translit=sljedujet
# 80	на	_	_	_	_	_	_	_	Translit=na
# 81	север	_	_	_	_	_	_	_	Translit=sjevjer
# 82	до	_	_	_	_	_	_	_	Translit=do
# 83	японского	_	_	_	_	_	_	_	Translit=Japonskogo
# 84	побережья	_	_	_	_	_	_	_	Translit=pobjerjezhьja
# 85	,	_	_	_	_	_	_	_	Translit=,
# 86	оказывая	_	_	_	_	_	_	_	Translit=okazyvaja
# 87	заметное	_	_	_	_	_	_	_	Translit=zamjetnoje
# 88	влияние	_	_	_	_	_	_	_	Translit=vlijanije
# 89	на	_	_	_	_	_	_	_	Translit=na
# 90	климат	_	_	_	_	_	_	_	Translit=klimat
# 91	японского	_	_	_	_	_	_	_	Translit=japonskogo
# 92	побережья	_	_	_	_	_	_	_	Translit=pobjerjezhьja
# 93	.	_	_	_	_	_	_	_	Translit=.
# 94	у	_	_	_	_	_	_	_	Translit=U
# 95	40°	_	_	_	_	_	_	_	Translit=40°
# 96	с	_	_	_	_	_	_	_	Translit=s
# 97	.	_	_	_	_	_	_	_	Translit=.
# 98	ш	_	_	_	_	_	_	_	Translit=sh
# 99	.	_	_	_	_	_	_	_	Translit=.
# 100	куросио	_	_	_	_	_	_	_	Translit=Kurosio
# 101	переходит	_	_	_	_	_	_	_	Translit=pjerjehodit
# 102	в	_	_	_	_	_	_	_	Translit=v
# 103	северное	_	_	_	_	_	_	_	Translit=Sjevjernoje
# 104	тихоокеанское	_	_	_	_	_	_	_	Translit=Tihookjeanskoje
# 105	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 106	,	_	_	_	_	_	_	_	Translit=,
# 107	следующее	_	_	_	_	_	_	_	Translit=sljedujush'jeje
# 108	на	_	_	_	_	_	_	_	Translit=na
# 109	восток	_	_	_	_	_	_	_	Translit=vostok
# 110	к	_	_	_	_	_	_	_	Translit=k
# 111	побережью	_	_	_	_	_	_	_	Translit=pobjerjezhьju
# 112	орегона	_	_	_	_	_	_	_	Translit=Rrjegona
# 113	.	_	_	_	_	_	_	_	Translit=.
# 114	сталкиваясь	_	_	_	_	_	_	_	Translit=Stalkivajasь
# 115	с	_	_	_	_	_	_	_	Translit=s
# 116	северной	_	_	_	_	_	_	_	Translit=Sjevjernoj
# 117	америкой	_	_	_	_	_	_	_	Translit=Amjerikoj
# 118	,	_	_	_	_	_	_	_	Translit=,
# 119	оно	_	_	_	_	_	_	_	Translit=ono
# 120	разделяется	_	_	_	_	_	_	_	Translit=razdjeljajetsja
# 121	на	_	_	_	_	_	_	_	Translit=na
# 122	северную	_	_	_	_	_	_	_	Translit=sjevjernuju
# 123	ветвь	_	_	_	_	_	_	_	Translit=vjetvь
# 124	тёплого	_	_	_	_	_	_	_	Translit=tёplogo
# 125	аляскинского	_	_	_	_	_	_	_	Translit=Aljaskinskogo
# 126	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 127	(	_	_	_	_	_	_	_	Translit=(
# 128	проходящего	_	_	_	_	_	_	_	Translit=prohodjash'jego
# 129	вдоль	_	_	_	_	_	_	_	Translit=vdolь
# 130	материка	_	_	_	_	_	_	_	Translit=matjerika
# 131	до	_	_	_	_	_	_	_	Translit=do
# 132	полуострова	_	_	_	_	_	_	_	Translit=poluostrova
# 133	аляска	_	_	_	_	_	_	_	Translit=Aljaska
# 134	)	_	_	_	_	_	_	_	Translit=)
# 135	и	_	_	_	_	_	_	_	Translit=i
# 136	южную	_	_	_	_	_	_	_	Translit=juzhnuju
# 137	—	_	_	_	_	_	_	_	Translit=—
# 138	холодного	_	_	_	_	_	_	_	Translit=holodnogo
# 139	калифорнийского	_	_	_	_	_	_	_	Translit=Kalifornijskogo
# 140	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 141	(	_	_	_	_	_	_	_	Translit=(
# 142	вдоль	_	_	_	_	_	_	_	Translit=vdolь
# 143	калифорнийского	_	_	_	_	_	_	_	Translit=Kalifornijskogo
# 144	полуострова	_	_	_	_	_	_	_	Translit=poluostrova
# 145	,	_	_	_	_	_	_	_	Translit=,
# 146	вливаясь	_	_	_	_	_	_	_	Translit=vlivajasь
# 147	в	_	_	_	_	_	_	_	Translit=v
# 148	северо-пассатное	_	_	_	_	_	_	_	Translit=Sjevjero-Oassatnoje
# 149	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 150	,	_	_	_	_	_	_	_	Translit=,
# 151	замыкая	_	_	_	_	_	_	_	Translit=zamykaja
# 152	круг	_	_	_	_	_	_	_	Translit=krug
# 153	)	_	_	_	_	_	_	_	Translit=)
# 154	.	_	_	_	_	_	_	_	Translit=.
# 155	в	_	_	_	_	_	_	_	Translit=V
# 156	южном	_	_	_	_	_	_	_	Translit=juzhnom
# 157	полушарии	_	_	_	_	_	_	_	Translit=polusharii
# 158	юго-восточный	_	_	_	_	_	_	_	Translit=Jugo-vostochnyj
# 159	пассат	_	_	_	_	_	_	_	Translit=passat
# 160	формирует	_	_	_	_	_	_	_	Translit=formirujet
# 161	южное	_	_	_	_	_	_	_	Translit=Juzhnoje
# 162	пассатное	_	_	_	_	_	_	_	Translit=Oassatnoje
# 163	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 164	,	_	_	_	_	_	_	_	Translit=,
# 165	которое	_	_	_	_	_	_	_	Translit=kotoroje
# 166	пересекает	_	_	_	_	_	_	_	Translit=pjerjesjekajet
# 167	тихий	_	_	_	_	_	_	_	Translit=Tihij
# 168	океан	_	_	_	_	_	_	_	Translit=okjean
# 169	от	_	_	_	_	_	_	_	Translit=ot
# 170	берегов	_	_	_	_	_	_	_	Translit=bjerjegov
# 171	колумбии	_	_	_	_	_	_	_	Translit=Kolumbii
# 172	до	_	_	_	_	_	_	_	Translit=do
# 173	молуккских	_	_	_	_	_	_	_	Translit=Molukkskih
# 174	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 175	.	_	_	_	_	_	_	_	Translit=.
# 176	между	_	_	_	_	_	_	_	Translit=Mjezhdu
# 177	островами	_	_	_	_	_	_	_	Translit=ostrovami
# 178	лайн	_	_	_	_	_	_	_	Translit=Lajn
# 179	и	_	_	_	_	_	_	_	Translit=i
# 180	туамоту	_	_	_	_	_	_	_	Translit=Tuamotu
# 181	оно	_	_	_	_	_	_	_	Translit=ono
# 182	образует	_	_	_	_	_	_	_	Translit=obrazujet
# 183	ответвление	_	_	_	_	_	_	_	Translit=otvjetvljenije
# 184	,	_	_	_	_	_	_	_	Translit=,
# 185	следующее	_	_	_	_	_	_	_	Translit=sljedujush'jeje
# 186	в	_	_	_	_	_	_	_	Translit=v
# 187	коралловое	_	_	_	_	_	_	_	Translit=Korallovoje
# 188	море	_	_	_	_	_	_	_	Translit=morje
# 189	и	_	_	_	_	_	_	_	Translit=i
# 190	далее	_	_	_	_	_	_	_	Translit=daljeje
# 191	на	_	_	_	_	_	_	_	Translit=na
# 192	юг	_	_	_	_	_	_	_	Translit=jug
# 193	вдоль	_	_	_	_	_	_	_	Translit=vdolь
# 194	берега	_	_	_	_	_	_	_	Translit=bjerjega
# 195	австралии	_	_	_	_	_	_	_	Translit=Avstralii
# 196	,	_	_	_	_	_	_	_	Translit=,
# 197	образуя	_	_	_	_	_	_	_	Translit=obrazuja
# 198	восточно-австралийское	_	_	_	_	_	_	_	Translit=Vostochno-Avstralijskoje
# 199	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 200	.	_	_	_	_	_	_	_	Translit=.
# 201	основные	_	_	_	_	_	_	_	Translit=Rsnovnyje
# 202	массы	_	_	_	_	_	_	_	Translit=massy
# 203	южного	_	_	_	_	_	_	_	Translit=Juzhnogo
# 204	пассатного	_	_	_	_	_	_	_	Translit=Oassatnogo
# 205	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 206	восточнее	_	_	_	_	_	_	_	Translit=vostochnjeje
# 207	молуккских	_	_	_	_	_	_	_	Translit=Molukkskih
# 208	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 209	сливаются	_	_	_	_	_	_	_	Translit=slivajutsja
# 210	с	_	_	_	_	_	_	_	Translit=s
# 211	южной	_	_	_	_	_	_	_	Translit=juzhnoj
# 212	ветвью	_	_	_	_	_	_	_	Translit=vjetvьju
# 213	северо-пассатного	_	_	_	_	_	_	_	Translit=Sjevjero-Oassatnogo
# 214	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 215	и	_	_	_	_	_	_	_	Translit=i
# 216	совместно	_	_	_	_	_	_	_	Translit=sovmjestno
# 217	образуют	_	_	_	_	_	_	_	Translit=obrazujut
# 218	экваториальное	_	_	_	_	_	_	_	Translit=Ekvatorialьnoje
# 219	противотечение	_	_	_	_	_	_	_	Translit=protivotjechjenije
# 220	.	_	_	_	_	_	_	_	Translit=.
# 221	восточно-австралийское	_	_	_	_	_	_	_	Translit=Vostochno-avstralijskoje
# 222	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 223	южнее	_	_	_	_	_	_	_	Translit=juzhnjeje
# 224	новой	_	_	_	_	_	_	_	Translit=Novoj
# 225	зеландии	_	_	_	_	_	_	_	Translit=Zjelandii
# 226	вливается	_	_	_	_	_	_	_	Translit=vlivajetsja
# 227	в	_	_	_	_	_	_	_	Translit=v
# 228	мощное	_	_	_	_	_	_	_	Translit=mosh'noje
# 229	антарктическое	_	_	_	_	_	_	_	Translit=Antarktichjeskoje
# 230	циркумполярное	_	_	_	_	_	_	_	Translit=tsirkumpoljarnoje
# 231	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 232	,	_	_	_	_	_	_	_	Translit=,
# 233	идущее	_	_	_	_	_	_	_	Translit=idush'jeje
# 234	из	_	_	_	_	_	_	_	Translit=iz
# 235	индийского	_	_	_	_	_	_	_	Translit=Indijskogo
# 236	океана	_	_	_	_	_	_	_	Translit=okjeana
# 237	,	_	_	_	_	_	_	_	Translit=,
# 238	пересекающее	_	_	_	_	_	_	_	Translit=pjerjesjekajush'jeje
# 239	тихий	_	_	_	_	_	_	_	Translit=Tihij
# 240	океан	_	_	_	_	_	_	_	Translit=okjean
# 241	с	_	_	_	_	_	_	_	Translit=s
# 242	запада	_	_	_	_	_	_	_	Translit=zapada
# 243	на	_	_	_	_	_	_	_	Translit=na
# 244	восток	_	_	_	_	_	_	_	Translit=vostok
# 245	.	_	_	_	_	_	_	_	Translit=.
# 246	у	_	_	_	_	_	_	_	Translit=U
# 247	южного	_	_	_	_	_	_	_	Translit=juzhnogo
# 248	окончания	_	_	_	_	_	_	_	Translit=okonchanija
# 249	южной	_	_	_	_	_	_	_	Translit=Juzhnoj
# 250	америки	_	_	_	_	_	_	_	Translit=Amjeriki
# 251	это	_	_	_	_	_	_	_	Translit=eto
# 252	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 253	ответвляется	_	_	_	_	_	_	_	Translit=otvjetvljajetsja
# 254	на	_	_	_	_	_	_	_	Translit=na
# 255	север	_	_	_	_	_	_	_	Translit=sjevjer
# 256	в	_	_	_	_	_	_	_	Translit=v
# 257	виде	_	_	_	_	_	_	_	Translit=vidje
# 258	перуанского	_	_	_	_	_	_	_	Translit=Ojeruanskogo
# 259	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 260	,	_	_	_	_	_	_	_	Translit=,
# 261	которое	_	_	_	_	_	_	_	Translit=kotoroje
# 262	в	_	_	_	_	_	_	_	Translit=v
# 263	тропиках	_	_	_	_	_	_	_	Translit=tropikah
# 264	вливается	_	_	_	_	_	_	_	Translit=vlivajetsja
# 265	в	_	_	_	_	_	_	_	Translit=v
# 266	южное	_	_	_	_	_	_	_	Translit=Juzhnoje
# 267	пассатное	_	_	_	_	_	_	_	Translit=Oassatnoje
# 268	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 269	,	_	_	_	_	_	_	_	Translit=,
# 270	замыкая	_	_	_	_	_	_	_	Translit=zamykaja
# 271	южный	_	_	_	_	_	_	_	Translit=juzhnyj
# 272	круг	_	_	_	_	_	_	_	Translit=krug
# 273	течений	_	_	_	_	_	_	_	Translit=tjechjenij
# 274	.	_	_	_	_	_	_	_	Translit=.
# 275	другая	_	_	_	_	_	_	_	Translit=Drugaja
# 276	ветвь	_	_	_	_	_	_	_	Translit=vjetvь
# 277	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 278	западных	_	_	_	_	_	_	_	Translit=Zapadnyh
# 279	ветров	_	_	_	_	_	_	_	Translit=vjetrov
# 280	огибает	_	_	_	_	_	_	_	Translit=ogibajet
# 281	южную	_	_	_	_	_	_	_	Translit=Juzhnuju
# 282	америку	_	_	_	_	_	_	_	Translit=Amjeriku
# 283	под	_	_	_	_	_	_	_	Translit=pod
# 284	названием	_	_	_	_	_	_	_	Translit=nazvanijem
# 285	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 286	мыса	_	_	_	_	_	_	_	Translit=mysa
# 287	горн	_	_	_	_	_	_	_	Translit=Gorn
# 288	и	_	_	_	_	_	_	_	Translit=i
# 289	уходит	_	_	_	_	_	_	_	Translit=uhodit
# 290	в	_	_	_	_	_	_	_	Translit=v
# 291	атлантический	_	_	_	_	_	_	_	Translit=Atlantichjeskij
# 292	океан	_	_	_	_	_	_	_	Translit=okjean
# 293	.	_	_	_	_	_	_	_	Translit=.
# 294	важная	_	_	_	_	_	_	_	Translit=Vazhnaja
# 295	роль	_	_	_	_	_	_	_	Translit=rolь
# 296	в	_	_	_	_	_	_	_	Translit=v
# 297	циркуляции	_	_	_	_	_	_	_	Translit=tsirkuljatsii
# 298	вод	_	_	_	_	_	_	_	Translit=vod
# 299	тихого	_	_	_	_	_	_	_	Translit=Tihogo
# 300	океана	_	_	_	_	_	_	_	Translit=okjeana
# 301	принадлежит	_	_	_	_	_	_	_	Translit=prinadljezhit
# 302	холодному	_	_	_	_	_	_	_	Translit=holodnomu
# 303	подповерхностному	_	_	_	_	_	_	_	Translit=podpovjerhnostnomu
# 304	течению	_	_	_	_	_	_	_	Translit=tjechjeniju
# 305	кромвелла	_	_	_	_	_	_	_	Translit=Kromvjella
# 306	,	_	_	_	_	_	_	_	Translit=,
# 307	протекающему	_	_	_	_	_	_	_	Translit=protjekajush'jemu
# 308	под	_	_	_	_	_	_	_	Translit=pod
# 309	южным	_	_	_	_	_	_	_	Translit=Juzhnym
# 310	пассатным	_	_	_	_	_	_	_	Translit=Oassatnym
# 311	течением	_	_	_	_	_	_	_	Translit=tjechjenijem
# 312	от	_	_	_	_	_	_	_	Translit=ot
# 313	154°	_	_	_	_	_	_	_	Translit=154°
# 314	з	_	_	_	_	_	_	_	Translit=z
# 315	.	_	_	_	_	_	_	_	Translit=.
# 316	д	_	_	_	_	_	_	_	Translit=d
# 317	.	_	_	_	_	_	_	_	Translit=.
# 318	до	_	_	_	_	_	_	_	Translit=do
# 319	района	_	_	_	_	_	_	_	Translit=rajona
# 320	галапагосских	_	_	_	_	_	_	_	Translit=Galapagosskih
# 321	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 322	.	_	_	_	_	_	_	_	Translit=.
# 323	летом	_	_	_	_	_	_	_	Translit=Ljetom
# 324	в	_	_	_	_	_	_	_	Translit=v
# 325	восточной	_	_	_	_	_	_	_	Translit=vostochnoj
# 326	экваториальной	_	_	_	_	_	_	_	Translit=ekvatorialьnoj
# 327	части	_	_	_	_	_	_	_	Translit=chasti
# 328	океана	_	_	_	_	_	_	_	Translit=okjeana
# 329	наблюдается	_	_	_	_	_	_	_	Translit=nabljudajetsja
# 330	эль-ниньо	_	_	_	_	_	_	_	Translit=Elь-Ninьo
# 331	,	_	_	_	_	_	_	_	Translit=,
# 332	когда	_	_	_	_	_	_	_	Translit=kogda
# 333	тёплое	_	_	_	_	_	_	_	Translit=tёploje
# 334	слабосолёное	_	_	_	_	_	_	_	Translit=slabosolёnoje
# 335	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 336	оттесняет	_	_	_	_	_	_	_	Translit=ottjesnjajet
# 337	холодное	_	_	_	_	_	_	_	Translit=holodnoje
# 338	перуанское	_	_	_	_	_	_	_	Translit=Ojeruanskoje
# 339	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 340	от	_	_	_	_	_	_	_	Translit=ot
# 341	берегов	_	_	_	_	_	_	_	Translit=bjerjegov
# 342	южной	_	_	_	_	_	_	_	Translit=Juzhnoj
# 343	америки	_	_	_	_	_	_	_	Translit=Amjeriki
# 344	.	_	_	_	_	_	_	_	Translit=.
# 345	при	_	_	_	_	_	_	_	Translit=Ori
# 346	этом	_	_	_	_	_	_	_	Translit=etom
# 347	прекращается	_	_	_	_	_	_	_	Translit=prjekrash'ajetsja
# 348	поступление	_	_	_	_	_	_	_	Translit=postupljenije
# 349	кислорода	_	_	_	_	_	_	_	Translit=kisloroda
# 350	в	_	_	_	_	_	_	_	Translit=v
# 351	подповерхностные	_	_	_	_	_	_	_	Translit=podpovjerhnostnyje
# 352	слои	_	_	_	_	_	_	_	Translit=sloi
# 353	,	_	_	_	_	_	_	_	Translit=,
# 354	что	_	_	_	_	_	_	_	Translit=chto
# 355	приводит	_	_	_	_	_	_	_	Translit=privodit
# 356	к	_	_	_	_	_	_	_	Translit=k
# 357	гибели	_	_	_	_	_	_	_	Translit=gibjeli
# 358	планктона	_	_	_	_	_	_	_	Translit=planktona
# 359	,	_	_	_	_	_	_	_	Translit=,
# 360	рыб	_	_	_	_	_	_	_	Translit=ryb
# 361	и	_	_	_	_	_	_	_	Translit=i
# 362	питающихся	_	_	_	_	_	_	_	Translit=pitajush'ihsja
# 363	ими	_	_	_	_	_	_	_	Translit=imi
# 364	птиц	_	_	_	_	_	_	_	Translit=ptits
# 365	,	_	_	_	_	_	_	_	Translit=,
# 366	а	_	_	_	_	_	_	_	Translit=a
# 367	на	_	_	_	_	_	_	_	Translit=na
# 368	обычно	_	_	_	_	_	_	_	Translit=obychno
# 369	засушливое	_	_	_	_	_	_	_	Translit=zasushlivoje
# 370	побережье	_	_	_	_	_	_	_	Translit=pobjerjezhьje
# 371	обрушиваются	_	_	_	_	_	_	_	Translit=obrushivajutsja
# 372	обильные	_	_	_	_	_	_	_	Translit=obilьnyje
# 373	дожди	_	_	_	_	_	_	_	Translit=dozhdi
# 374	,	_	_	_	_	_	_	_	Translit=,
# 375	вызывающие	_	_	_	_	_	_	_	Translit=vyzyvajush'ije
# 376	катастрофические	_	_	_	_	_	_	_	Translit=katastrofichjeskije
# 377	наводнения	_	_	_	_	_	_	_	Translit=navodnjenija
# 378	.	_	_	_	_	_	_	_	Translit=.
