# %%
import sys
import re

# %%
file = open('test.txt', 'r', encoding='utf-8')
letters = open('transliterated_letters.txt', 'r', encoding='utf-8')
index = 0
translit = {}

for line in letters:
    line = line.replace('\n', '')
    line = line.split('    ')
    translit[line[0]] = line[1]
    
for word in file:
    word = word.strip().split(' ')
    for w in word:
        w = re.sub('([?!,.—:;()])', '', w)
        while index >= 0:
            index += 1
            break
        tr = w
        for key, value in translit.items():
                tr = tr.replace(key, value)
        print('%d\t'% (index) + '%s\t_\t_\t_\t_\t_\t_\t_\t' % (w) + 'Translit=%s'% (tr))

file.close()
# Out:
# 1	1	_	_	_	_	_	_	_	Translit=1
# 2	апріля	_	_	_	_	_	_	_	Translit=aprіlja
# 3	Перше	_	_	_	_	_	_	_	Translit=Ojershje
# 4	апріля	_	_	_	_	_	_	_	Translit=aprіlja
# 5		_	_	_	_	_	_	_	Translit=
# 6	91	_	_	_	_	_	_	_	Translit=91
# 7	день	_	_	_	_	_	_	_	Translit=djenь
# 8	рока	_	_	_	_	_	_	_	Translit=roka
# 9	92	_	_	_	_	_	_	_	Translit=92
# 10	в	_	_	_	_	_	_	_	Translit=v
# 11	переступнім	_	_	_	_	_	_	_	Translit=pjerjestupnіm
# 12	роцї	_	_	_	_	_	_	_	Translit=rotsї
# 13	в	_	_	_	_	_	_	_	Translit=v
# 14	ґреґоріаньскім	_	_	_	_	_	_	_	Translit=ґrjeґorіanьskіm
# 15	календарю	_	_	_	_	_	_	_	Translit=kaljendarju
# 16	До	_	_	_	_	_	_	_	Translit=Do
# 17	кінце	_	_	_	_	_	_	_	Translit=kіntsje
# 18	рока	_	_	_	_	_	_	_	Translit=roka
# 19	оставать	_	_	_	_	_	_	_	Translit=ostavatь
# 20		_	_	_	_	_	_	_	Translit=
# 21	Общую	_	_	_	_	_	_	_	Translit=Rbsh'uju
# 22	схему	_	_	_	_	_	_	_	Translit=shjemu
# 23	течений	_	_	_	_	_	_	_	Translit=tjechjenij
# 24	Тихого	_	_	_	_	_	_	_	Translit=Tihogo
# 25	океана	_	_	_	_	_	_	_	Translit=okjeana
# 26	определяют	_	_	_	_	_	_	_	Translit=oprjedjeljajut
# 27	закономерности	_	_	_	_	_	_	_	Translit=zakonomjernosti
# 28	общей	_	_	_	_	_	_	_	Translit=obsh'jej
# 29	циркуляции	_	_	_	_	_	_	_	Translit=tsirkuljatsii
# 30	атмосферы	_	_	_	_	_	_	_	Translit=atmosfjery
# 31	Северо-восточный	_	_	_	_	_	_	_	Translit=Sjevjero-vostochnyj
# 32	пассат	_	_	_	_	_	_	_	Translit=passat
# 33	северного	_	_	_	_	_	_	_	Translit=sjevjernogo
# 34	полушария	_	_	_	_	_	_	_	Translit=polusharija
# 35	способствует	_	_	_	_	_	_	_	Translit=sposobstvujet
# 36	возникновению	_	_	_	_	_	_	_	Translit=vozniknovjeniju
# 37	Северо-Пассатного	_	_	_	_	_	_	_	Translit=Sjevjero-Oassatnogo
# 38	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 39	пересекающего	_	_	_	_	_	_	_	Translit=pjerjesjekajush'jego
# 40	океан	_	_	_	_	_	_	_	Translit=okjean
# 41	от	_	_	_	_	_	_	_	Translit=ot
# 42	Центрально-американского	_	_	_	_	_	_	_	Translit=Tsjentralьno-amjerikanskogo
# 43	побережья	_	_	_	_	_	_	_	Translit=pobjerjezhьja
# 44	до	_	_	_	_	_	_	_	Translit=do
# 45	Филиппинских	_	_	_	_	_	_	_	Translit=Filippinskih
# 46	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 47	Далее	_	_	_	_	_	_	_	Translit=Daljeje
# 48	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 49	разделяется	_	_	_	_	_	_	_	Translit=razdjeljajetsja
# 50	на	_	_	_	_	_	_	_	Translit=na
# 51	два	_	_	_	_	_	_	_	Translit=dva
# 52	рукава	_	_	_	_	_	_	_	Translit=rukava
# 53	один	_	_	_	_	_	_	_	Translit=odin
# 54	отклоняется	_	_	_	_	_	_	_	Translit=otklonjajetsja
# 55	к	_	_	_	_	_	_	_	Translit=k
# 56	югу	_	_	_	_	_	_	_	Translit=jugu
# 57	и	_	_	_	_	_	_	_	Translit=i
# 58	частью	_	_	_	_	_	_	_	Translit=chastьju
# 59	питает	_	_	_	_	_	_	_	Translit=pitajet
# 60	Экваториальное	_	_	_	_	_	_	_	Translit=Ekvatorialьnoje
# 61	противотечение	_	_	_	_	_	_	_	Translit=protivotjechjenije
# 62	а	_	_	_	_	_	_	_	Translit=a
# 63	частью	_	_	_	_	_	_	_	Translit=chastьju
# 64	растекается	_	_	_	_	_	_	_	Translit=rastjekajetsja
# 65	по	_	_	_	_	_	_	_	Translit=po
# 66	бассейнам	_	_	_	_	_	_	_	Translit=bassjejnam
# 67	индонезийских	_	_	_	_	_	_	_	Translit=indonjezijskih
# 68	морей	_	_	_	_	_	_	_	Translit=morjej
# 69	Северный	_	_	_	_	_	_	_	Translit=Sjevjernyj
# 70	рукав	_	_	_	_	_	_	_	Translit=rukav
# 71	следует	_	_	_	_	_	_	_	Translit=sljedujet
# 72	в	_	_	_	_	_	_	_	Translit=v
# 73	Восточно-Китайское	_	_	_	_	_	_	_	Translit=Vostochno-Kitajskoje
# 74	море	_	_	_	_	_	_	_	Translit=morje
# 75	и	_	_	_	_	_	_	_	Translit=i
# 76	выходя	_	_	_	_	_	_	_	Translit=vyhodja
# 77	из	_	_	_	_	_	_	_	Translit=iz
# 78	него	_	_	_	_	_	_	_	Translit=njego
# 79	южнее	_	_	_	_	_	_	_	Translit=juzhnjeje
# 80	острова	_	_	_	_	_	_	_	Translit=ostrova
# 81	Кюсю	_	_	_	_	_	_	_	Translit=Kjusju
# 82	даёт	_	_	_	_	_	_	_	Translit=daёt
# 83	начало	_	_	_	_	_	_	_	Translit=nachalo
# 84	мощному	_	_	_	_	_	_	_	Translit=mosh'nomu
# 85	тёплому	_	_	_	_	_	_	_	Translit=tёplomu
# 86	течению	_	_	_	_	_	_	_	Translit=tjechjeniju
# 87	Куросио	_	_	_	_	_	_	_	Translit=Kurosio
# 88	Это	_	_	_	_	_	_	_	Translit=Eto
# 89	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 90	следует	_	_	_	_	_	_	_	Translit=sljedujet
# 91	на	_	_	_	_	_	_	_	Translit=na
# 92	север	_	_	_	_	_	_	_	Translit=sjevjer
# 93	до	_	_	_	_	_	_	_	Translit=do
# 94	Японского	_	_	_	_	_	_	_	Translit=Japonskogo
# 95	побережья	_	_	_	_	_	_	_	Translit=pobjerjezhьja
# 96	оказывая	_	_	_	_	_	_	_	Translit=okazyvaja
# 97	заметное	_	_	_	_	_	_	_	Translit=zamjetnoje
# 98	влияние	_	_	_	_	_	_	_	Translit=vlijanije
# 99	на	_	_	_	_	_	_	_	Translit=na
# 100	климат	_	_	_	_	_	_	_	Translit=klimat
# 101	японского	_	_	_	_	_	_	_	Translit=japonskogo
# 102	побережья	_	_	_	_	_	_	_	Translit=pobjerjezhьja
# 103	У	_	_	_	_	_	_	_	Translit=U
# 104	40°	_	_	_	_	_	_	_	Translit=40°
# 105	с	_	_	_	_	_	_	_	Translit=s
# 106	ш	_	_	_	_	_	_	_	Translit=sh
# 107	Куросио	_	_	_	_	_	_	_	Translit=Kurosio
# 108	переходит	_	_	_	_	_	_	_	Translit=pjerjehodit
# 109	в	_	_	_	_	_	_	_	Translit=v
# 110	Северное	_	_	_	_	_	_	_	Translit=Sjevjernoje
# 111	Тихоокеанское	_	_	_	_	_	_	_	Translit=Tihookjeanskoje
# 112	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 113	следующее	_	_	_	_	_	_	_	Translit=sljedujush'jeje
# 114	на	_	_	_	_	_	_	_	Translit=na
# 115	восток	_	_	_	_	_	_	_	Translit=vostok
# 116	к	_	_	_	_	_	_	_	Translit=k
# 117	побережью	_	_	_	_	_	_	_	Translit=pobjerjezhьju
# 118	Орегона	_	_	_	_	_	_	_	Translit=Rrjegona
# 119	Сталкиваясь	_	_	_	_	_	_	_	Translit=Stalkivajasь
# 120	с	_	_	_	_	_	_	_	Translit=s
# 121	Северной	_	_	_	_	_	_	_	Translit=Sjevjernoj
# 122	Америкой	_	_	_	_	_	_	_	Translit=Amjerikoj
# 123	оно	_	_	_	_	_	_	_	Translit=ono
# 124	разделяется	_	_	_	_	_	_	_	Translit=razdjeljajetsja
# 125	на	_	_	_	_	_	_	_	Translit=na
# 126	северную	_	_	_	_	_	_	_	Translit=sjevjernuju
# 127	ветвь	_	_	_	_	_	_	_	Translit=vjetvь
# 128	тёплого	_	_	_	_	_	_	_	Translit=tёplogo
# 129	Аляскинского	_	_	_	_	_	_	_	Translit=Aljaskinskogo
# 130	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 131	проходящего	_	_	_	_	_	_	_	Translit=prohodjash'jego
# 132	вдоль	_	_	_	_	_	_	_	Translit=vdolь
# 133	материка	_	_	_	_	_	_	_	Translit=matjerika
# 134	до	_	_	_	_	_	_	_	Translit=do
# 135	полуострова	_	_	_	_	_	_	_	Translit=poluostrova
# 136	Аляска	_	_	_	_	_	_	_	Translit=Aljaska
# 137	и	_	_	_	_	_	_	_	Translit=i
# 138	южную	_	_	_	_	_	_	_	Translit=juzhnuju
# 139		_	_	_	_	_	_	_	Translit=
# 140	холодного	_	_	_	_	_	_	_	Translit=holodnogo
# 141	Калифорнийского	_	_	_	_	_	_	_	Translit=Kalifornijskogo
# 142	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 143	вдоль	_	_	_	_	_	_	_	Translit=vdolь
# 144	Калифорнийского	_	_	_	_	_	_	_	Translit=Kalifornijskogo
# 145	полуострова	_	_	_	_	_	_	_	Translit=poluostrova
# 146	вливаясь	_	_	_	_	_	_	_	Translit=vlivajasь
# 147	в	_	_	_	_	_	_	_	Translit=v
# 148	Северо-Пассатное	_	_	_	_	_	_	_	Translit=Sjevjero-Oassatnoje
# 149	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 150	замыкая	_	_	_	_	_	_	_	Translit=zamykaja
# 151	круг	_	_	_	_	_	_	_	Translit=krug
# 152	В	_	_	_	_	_	_	_	Translit=V
# 153	южном	_	_	_	_	_	_	_	Translit=juzhnom
# 154	полушарии	_	_	_	_	_	_	_	Translit=polusharii
# 155	Юго-восточный	_	_	_	_	_	_	_	Translit=Jugo-vostochnyj
# 156	пассат	_	_	_	_	_	_	_	Translit=passat
# 157	формирует	_	_	_	_	_	_	_	Translit=formirujet
# 158	Южное	_	_	_	_	_	_	_	Translit=Juzhnoje
# 159	Пассатное	_	_	_	_	_	_	_	Translit=Oassatnoje
# 160	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 161	которое	_	_	_	_	_	_	_	Translit=kotoroje
# 162	пересекает	_	_	_	_	_	_	_	Translit=pjerjesjekajet
# 163	Тихий	_	_	_	_	_	_	_	Translit=Tihij
# 164	океан	_	_	_	_	_	_	_	Translit=okjean
# 165	от	_	_	_	_	_	_	_	Translit=ot
# 166	берегов	_	_	_	_	_	_	_	Translit=bjerjegov
# 167	Колумбии	_	_	_	_	_	_	_	Translit=Kolumbii
# 168	до	_	_	_	_	_	_	_	Translit=do
# 169	Молуккских	_	_	_	_	_	_	_	Translit=Molukkskih
# 170	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 171	Между	_	_	_	_	_	_	_	Translit=Mjezhdu
# 172	островами	_	_	_	_	_	_	_	Translit=ostrovami
# 173	Лайн	_	_	_	_	_	_	_	Translit=Lajn
# 174	и	_	_	_	_	_	_	_	Translit=i
# 175	Туамоту	_	_	_	_	_	_	_	Translit=Tuamotu
# 176	оно	_	_	_	_	_	_	_	Translit=ono
# 177	образует	_	_	_	_	_	_	_	Translit=obrazujet
# 178	ответвление	_	_	_	_	_	_	_	Translit=otvjetvljenije
# 179	следующее	_	_	_	_	_	_	_	Translit=sljedujush'jeje
# 180	в	_	_	_	_	_	_	_	Translit=v
# 181	Коралловое	_	_	_	_	_	_	_	Translit=Korallovoje
# 182	море	_	_	_	_	_	_	_	Translit=morje
# 183	и	_	_	_	_	_	_	_	Translit=i
# 184	далее	_	_	_	_	_	_	_	Translit=daljeje
# 185	на	_	_	_	_	_	_	_	Translit=na
# 186	юг	_	_	_	_	_	_	_	Translit=jug
# 187	вдоль	_	_	_	_	_	_	_	Translit=vdolь
# 188	берега	_	_	_	_	_	_	_	Translit=bjerjega
# 189	Австралии	_	_	_	_	_	_	_	Translit=Avstralii
# 190	образуя	_	_	_	_	_	_	_	Translit=obrazuja
# 191	Восточно-Австралийское	_	_	_	_	_	_	_	Translit=Vostochno-Avstralijskoje
# 192	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 193	Основные	_	_	_	_	_	_	_	Translit=Rsnovnyje
# 194	массы	_	_	_	_	_	_	_	Translit=massy
# 195	Южного	_	_	_	_	_	_	_	Translit=Juzhnogo
# 196	Пассатного	_	_	_	_	_	_	_	Translit=Oassatnogo
# 197	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 198	восточнее	_	_	_	_	_	_	_	Translit=vostochnjeje
# 199	Молуккских	_	_	_	_	_	_	_	Translit=Molukkskih
# 200	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 201	сливаются	_	_	_	_	_	_	_	Translit=slivajutsja
# 202	с	_	_	_	_	_	_	_	Translit=s
# 203	южной	_	_	_	_	_	_	_	Translit=juzhnoj
# 204	ветвью	_	_	_	_	_	_	_	Translit=vjetvьju
# 205	Северо-Пассатного	_	_	_	_	_	_	_	Translit=Sjevjero-Oassatnogo
# 206	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 207	и	_	_	_	_	_	_	_	Translit=i
# 208	совместно	_	_	_	_	_	_	_	Translit=sovmjestno
# 209	образуют	_	_	_	_	_	_	_	Translit=obrazujut
# 210	Экваториальное	_	_	_	_	_	_	_	Translit=Ekvatorialьnoje
# 211	противотечение	_	_	_	_	_	_	_	Translit=protivotjechjenije
# 212	Восточно-австралийское	_	_	_	_	_	_	_	Translit=Vostochno-avstralijskoje
# 213	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 214	южнее	_	_	_	_	_	_	_	Translit=juzhnjeje
# 215	Новой	_	_	_	_	_	_	_	Translit=Novoj
# 216	Зеландии	_	_	_	_	_	_	_	Translit=Zjelandii
# 217	вливается	_	_	_	_	_	_	_	Translit=vlivajetsja
# 218	в	_	_	_	_	_	_	_	Translit=v
# 219	мощное	_	_	_	_	_	_	_	Translit=mosh'noje
# 220	Антарктическое	_	_	_	_	_	_	_	Translit=Antarktichjeskoje
# 221	циркумполярное	_	_	_	_	_	_	_	Translit=tsirkumpoljarnoje
# 222	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 223	идущее	_	_	_	_	_	_	_	Translit=idush'jeje
# 224	из	_	_	_	_	_	_	_	Translit=iz
# 225	Индийского	_	_	_	_	_	_	_	Translit=Indijskogo
# 226	океана	_	_	_	_	_	_	_	Translit=okjeana
# 227	пересекающее	_	_	_	_	_	_	_	Translit=pjerjesjekajush'jeje
# 228	Тихий	_	_	_	_	_	_	_	Translit=Tihij
# 229	океан	_	_	_	_	_	_	_	Translit=okjean
# 230	с	_	_	_	_	_	_	_	Translit=s
# 231	запада	_	_	_	_	_	_	_	Translit=zapada
# 232	на	_	_	_	_	_	_	_	Translit=na
# 233	восток	_	_	_	_	_	_	_	Translit=vostok
# 234	У	_	_	_	_	_	_	_	Translit=U
# 235	южного	_	_	_	_	_	_	_	Translit=juzhnogo
# 236	окончания	_	_	_	_	_	_	_	Translit=okonchanija
# 237	Южной	_	_	_	_	_	_	_	Translit=Juzhnoj
# 238	Америки	_	_	_	_	_	_	_	Translit=Amjeriki
# 239	это	_	_	_	_	_	_	_	Translit=eto
# 240	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 241	ответвляется	_	_	_	_	_	_	_	Translit=otvjetvljajetsja
# 242	на	_	_	_	_	_	_	_	Translit=na
# 243	север	_	_	_	_	_	_	_	Translit=sjevjer
# 244	в	_	_	_	_	_	_	_	Translit=v
# 245	виде	_	_	_	_	_	_	_	Translit=vidje
# 246	Перуанского	_	_	_	_	_	_	_	Translit=Ojeruanskogo
# 247	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 248	которое	_	_	_	_	_	_	_	Translit=kotoroje
# 249	в	_	_	_	_	_	_	_	Translit=v
# 250	тропиках	_	_	_	_	_	_	_	Translit=tropikah
# 251	вливается	_	_	_	_	_	_	_	Translit=vlivajetsja
# 252	в	_	_	_	_	_	_	_	Translit=v
# 253	Южное	_	_	_	_	_	_	_	Translit=Juzhnoje
# 254	Пассатное	_	_	_	_	_	_	_	Translit=Oassatnoje
# 255	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 256	замыкая	_	_	_	_	_	_	_	Translit=zamykaja
# 257	южный	_	_	_	_	_	_	_	Translit=juzhnyj
# 258	круг	_	_	_	_	_	_	_	Translit=krug
# 259	течений	_	_	_	_	_	_	_	Translit=tjechjenij
# 260	Другая	_	_	_	_	_	_	_	Translit=Drugaja
# 261	ветвь	_	_	_	_	_	_	_	Translit=vjetvь
# 262	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 263	Западных	_	_	_	_	_	_	_	Translit=Zapadnyh
# 264	ветров	_	_	_	_	_	_	_	Translit=vjetrov
# 265	огибает	_	_	_	_	_	_	_	Translit=ogibajet
# 266	Южную	_	_	_	_	_	_	_	Translit=Juzhnuju
# 267	Америку	_	_	_	_	_	_	_	Translit=Amjeriku
# 268	под	_	_	_	_	_	_	_	Translit=pod
# 269	названием	_	_	_	_	_	_	_	Translit=nazvanijem
# 270	течения	_	_	_	_	_	_	_	Translit=tjechjenija
# 271	мыса	_	_	_	_	_	_	_	Translit=mysa
# 272	Горн	_	_	_	_	_	_	_	Translit=Gorn
# 273	и	_	_	_	_	_	_	_	Translit=i
# 274	уходит	_	_	_	_	_	_	_	Translit=uhodit
# 275	в	_	_	_	_	_	_	_	Translit=v
# 276	Атлантический	_	_	_	_	_	_	_	Translit=Atlantichjeskij
# 277	океан	_	_	_	_	_	_	_	Translit=okjean
# 278	Важная	_	_	_	_	_	_	_	Translit=Vazhnaja
# 279	роль	_	_	_	_	_	_	_	Translit=rolь
# 280	в	_	_	_	_	_	_	_	Translit=v
# 281	циркуляции	_	_	_	_	_	_	_	Translit=tsirkuljatsii
# 282	вод	_	_	_	_	_	_	_	Translit=vod
# 283	Тихого	_	_	_	_	_	_	_	Translit=Tihogo
# 284	океана	_	_	_	_	_	_	_	Translit=okjeana
# 285	принадлежит	_	_	_	_	_	_	_	Translit=prinadljezhit
# 286	холодному	_	_	_	_	_	_	_	Translit=holodnomu
# 287	подповерхностному	_	_	_	_	_	_	_	Translit=podpovjerhnostnomu
# 288	течению	_	_	_	_	_	_	_	Translit=tjechjeniju
# 289	Кромвелла	_	_	_	_	_	_	_	Translit=Kromvjella
# 290	протекающему	_	_	_	_	_	_	_	Translit=protjekajush'jemu
# 291	под	_	_	_	_	_	_	_	Translit=pod
# 292	Южным	_	_	_	_	_	_	_	Translit=Juzhnym
# 293	Пассатным	_	_	_	_	_	_	_	Translit=Oassatnym
# 294	течением	_	_	_	_	_	_	_	Translit=tjechjenijem
# 295	от	_	_	_	_	_	_	_	Translit=ot
# 296	154°	_	_	_	_	_	_	_	Translit=154°
# 297	з	_	_	_	_	_	_	_	Translit=z
# 298	д	_	_	_	_	_	_	_	Translit=d
# 299	до	_	_	_	_	_	_	_	Translit=do
# 300	района	_	_	_	_	_	_	_	Translit=rajona
# 301	Галапагосских	_	_	_	_	_	_	_	Translit=Galapagosskih
# 302	островов	_	_	_	_	_	_	_	Translit=ostrovov
# 303	Летом	_	_	_	_	_	_	_	Translit=Ljetom
# 304	в	_	_	_	_	_	_	_	Translit=v
# 305	восточной	_	_	_	_	_	_	_	Translit=vostochnoj
# 306	экваториальной	_	_	_	_	_	_	_	Translit=ekvatorialьnoj
# 307	части	_	_	_	_	_	_	_	Translit=chasti
# 308	океана	_	_	_	_	_	_	_	Translit=okjeana
# 309	наблюдается	_	_	_	_	_	_	_	Translit=nabljudajetsja
# 310	Эль-Ниньо	_	_	_	_	_	_	_	Translit=Elь-Ninьo
# 311	когда	_	_	_	_	_	_	_	Translit=kogda
# 312	тёплое	_	_	_	_	_	_	_	Translit=tёploje
# 313	слабосолёное	_	_	_	_	_	_	_	Translit=slabosolёnoje
# 314	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 315	оттесняет	_	_	_	_	_	_	_	Translit=ottjesnjajet
# 316	холодное	_	_	_	_	_	_	_	Translit=holodnoje
# 317	Перуанское	_	_	_	_	_	_	_	Translit=Ojeruanskoje
# 318	течение	_	_	_	_	_	_	_	Translit=tjechjenije
# 319	от	_	_	_	_	_	_	_	Translit=ot
# 320	берегов	_	_	_	_	_	_	_	Translit=bjerjegov
# 321	Южной	_	_	_	_	_	_	_	Translit=Juzhnoj
# 322	Америки	_	_	_	_	_	_	_	Translit=Amjeriki
# 323	При	_	_	_	_	_	_	_	Translit=Ori
# 324	этом	_	_	_	_	_	_	_	Translit=etom
# 325	прекращается	_	_	_	_	_	_	_	Translit=prjekrash'ajetsja
# 326	поступление	_	_	_	_	_	_	_	Translit=postupljenije
# 327	кислорода	_	_	_	_	_	_	_	Translit=kisloroda
# 328	в	_	_	_	_	_	_	_	Translit=v
# 329	подповерхностные	_	_	_	_	_	_	_	Translit=podpovjerhnostnyje
# 330	слои	_	_	_	_	_	_	_	Translit=sloi
# 331	что	_	_	_	_	_	_	_	Translit=chto
# 332	приводит	_	_	_	_	_	_	_	Translit=privodit
# 333	к	_	_	_	_	_	_	_	Translit=k
# 334	гибели	_	_	_	_	_	_	_	Translit=gibjeli
# 335	планктона	_	_	_	_	_	_	_	Translit=planktona
# 336	рыб	_	_	_	_	_	_	_	Translit=ryb
# 337	и	_	_	_	_	_	_	_	Translit=i
# 338	питающихся	_	_	_	_	_	_	_	Translit=pitajush'ihsja
# 339	ими	_	_	_	_	_	_	_	Translit=imi
# 340	птиц	_	_	_	_	_	_	_	Translit=ptits
# 341	а	_	_	_	_	_	_	_	Translit=a
# 342	на	_	_	_	_	_	_	_	Translit=na
# 343	обычно	_	_	_	_	_	_	_	Translit=obychno
# 344	засушливое	_	_	_	_	_	_	_	Translit=zasushlivoje
# 345	побережье	_	_	_	_	_	_	_	Translit=pobjerjezhьje
# 346	обрушиваются	_	_	_	_	_	_	_	Translit=obrushivajutsja
# 347	обильные	_	_	_	_	_	_	_	Translit=obilьnyje
# 348	дожди	_	_	_	_	_	_	_	Translit=dozhdi
# 349	вызывающие	_	_	_	_	_	_	_	Translit=vyzyvajush'ije
# 350	катастрофические	_	_	_	_	_	_	_	Translit=katastrofichjeskije
# 351	наводнения	_	_	_	_	_	_	_	Translit=navodnjenija
